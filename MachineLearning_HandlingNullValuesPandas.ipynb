# %%
import numpy

i = [11,55,64,20,11,8,9,66,20]

x = numpy.std(i)
print(x)
# Out:
# 23.380903889000244

# %%
import numpy

i = [32,111,138,28,59,77,97]
x = numpy.std(i)
print(x)
# Out:
# 37.84501153334721

# %%
import numpy

i = [32,111,138,28,59,77,97]
x = numpy.var(i)
print(x)
# Out:
# 1432.2448979591834

# %%
import numpy
age = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

i = numpy.percentile(age, 75)
print(i)
# Out:
# 43.0

# %%
import numpy

age = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
i = numpy.percentile(age, 90)
print(i)
# Out:
# 61.0

# %%
import numpy

i = numpy.random.uniform(1, 50, 200) 
print(i)
# Out:
# [39.32599555 40.08923257 49.30573534 40.59633739 14.95290344 11.91127207
#  26.38277016  8.38459964 46.02798978  7.15628049 36.46884529 40.35958695
#  32.19039495 45.04665567 27.15347247 30.89316286 15.04938124 22.3111007
#  25.73350261 44.2457865  31.69154556 27.82715268 35.1499335   9.21608976
#  25.21085927 16.40651367 33.07131034  1.22173037  7.30827002  7.30556997
#  24.32786663 13.24287861 30.29561711 41.23717076 17.44065137  5.73439384
#  28.66001601 36.69777075 11.9595086  38.15095532 41.2422228   4.0588761
#  36.82153726  3.86369376 33.07035673 26.35663103 31.03993779 21.16979246
#  19.09676934 17.65485093 13.40267403 18.20709065 23.14208851 24.67285517
#  46.54221095 16.52924404 21.24175366 36.10140682  2.19071334  1.04531811
#   1.70159408 37.75733231  9.18508754 47.23660982  5.35133906  1.82171937
#  25.9915144   9.36305824 36.83727388 43.42479485 44.23855706  8.09369395
#  36.25256384 34.28419774 46.01837374  5.31918012  6.69868605 17.64038219
# ...

# %%
import numpy

import matplotlib.pyplot as plt

i = numpy.random.uniform(1, 20, 200)
plt.hist(i, 5)

plt.show()

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv')
i
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-10                 0.0                0.0
# 1      Albania      ALB  2021-01-11                 NaN                NaN
# 2      Albania      ALB  2021-01-12               128.0              128.0
# 3      Albania      ALB  2021-01-13               188.0              188.0
# 4      Albania      ALB  2021-01-14               266.0              266.0
# ...        ...      ...         ...                 ...                ...
# 5967  Zimbabwe      ZWE  2021-03-07             32240.0            32240.0
# 5968  Zimbabwe      ZWE  2021-03-08             35518.0            35518.0
# 5969  Zimbabwe      ZWE  2021-03-09             35761.0            35761.0
# 5970  Zimbabwe      ZWE  2021-03-10             35901.0            35901.0
# 5971  Zimbabwe      ZWE  2021-03-11             36019.0            36019.0
#
# ...

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv', nrows = 4)

i
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# ...

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv', usecols = [0])

i
# Out:
#        country
# 0      Albania
# 1      Albania
# 2      Albania
# 3      Albania
# 4      Albania
# ...        ...
# 5967  Zimbabwe
# 5968  Zimbabwe
# 5969  Zimbabwe
# 5970  Zimbabwe
# 5971  Zimbabwe
#
# [5972 rows x 1 columns]

# %%
import pandas as pd
i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv', usecols = [0,1])
i
# Out:
#        country iso_code
# 0      Albania      ALB
# 1      Albania      ALB
# 2      Albania      ALB
# 3      Albania      ALB
# 4      Albania      ALB
# ...        ...      ...
# 5967  Zimbabwe      ZWE
# 5968  Zimbabwe      ZWE
# 5969  Zimbabwe      ZWE
# 5970  Zimbabwe      ZWE
# 5971  Zimbabwe      ZWE
#
# [5972 rows x 2 columns]

# %%
import pandas as pd
i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv', skiprows = 1)
i
# Out:
#        Albania  ALB  2021-01-10      0.0    0.0.1  Unnamed: 5  Unnamed: 6  \
# 0      Albania  ALB  2021-01-11      NaN      NaN         NaN         NaN
# 1      Albania  ALB  2021-01-12    128.0    128.0         NaN         NaN
# 2      Albania  ALB  2021-01-13    188.0    188.0         NaN        60.0
# 3      Albania  ALB  2021-01-14    266.0    266.0         NaN        78.0
# 4      Albania  ALB  2021-01-15    308.0    308.0         NaN        42.0
# ...        ...  ...         ...      ...      ...         ...         ...
# 5966  Zimbabwe  ZWE  2021-03-07  32240.0  32240.0         NaN       226.0
# 5967  Zimbabwe  ZWE  2021-03-08  35518.0  35518.0         NaN      3278.0
# 5968  Zimbabwe  ZWE  2021-03-09  35761.0  35761.0         NaN       243.0
# 5969  Zimbabwe  ZWE  2021-03-10  35901.0  35901.0         NaN       140.0
# 5970  Zimbabwe  ZWE  2021-03-11  36019.0  36019.0         NaN       118.0
#
#       Unnamed: 7  0.0.2  0.0.3  Unnamed: 10  Unnamed: 11    Pfizer/BioNTech  \
# ...

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv', skiprows = [1])

i
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-11                 NaN                NaN
# 1      Albania      ALB  2021-01-12               128.0              128.0
# 2      Albania      ALB  2021-01-13               188.0              188.0
# 3      Albania      ALB  2021-01-14               266.0              266.0
# 4      Albania      ALB  2021-01-15               308.0              308.0
# ...        ...      ...         ...                 ...                ...
# 5966  Zimbabwe      ZWE  2021-03-07             32240.0            32240.0
# 5967  Zimbabwe      ZWE  2021-03-08             35518.0            35518.0
# 5968  Zimbabwe      ZWE  2021-03-09             35761.0            35761.0
# 5969  Zimbabwe      ZWE  2021-03-10             35901.0            35901.0
# 5970  Zimbabwe      ZWE  2021-03-11             36019.0            36019.0
#
# ...

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv', index_col = 'country')
i
# Out:
#          iso_code        date  total_vaccinations  people_vaccinated  \
# country
# Albania       ALB  2021-01-10                 0.0                0.0
# Albania       ALB  2021-01-11                 NaN                NaN
# Albania       ALB  2021-01-12               128.0              128.0
# Albania       ALB  2021-01-13               188.0              188.0
# Albania       ALB  2021-01-14               266.0              266.0
# ...           ...         ...                 ...                ...
# Zimbabwe      ZWE  2021-03-07             32240.0            32240.0
# Zimbabwe      ZWE  2021-03-08             35518.0            35518.0
# Zimbabwe      ZWE  2021-03-09             35761.0            35761.0
# Zimbabwe      ZWE  2021-03-10             35901.0            35901.0
# Zimbabwe      ZWE  2021-03-11             36019.0            36019.0
#
#           people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# country
# ...

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv', index_col = 0)

i
# Out:
#          iso_code        date  total_vaccinations  people_vaccinated  \
# country
# Albania       ALB  2021-01-10                 0.0                0.0
# Albania       ALB  2021-01-11                 NaN                NaN
# Albania       ALB  2021-01-12               128.0              128.0
# Albania       ALB  2021-01-13               188.0              188.0
# Albania       ALB  2021-01-14               266.0              266.0
# ...           ...         ...                 ...                ...
# Zimbabwe      ZWE  2021-03-07             32240.0            32240.0
# Zimbabwe      ZWE  2021-03-08             35518.0            35518.0
# Zimbabwe      ZWE  2021-03-09             35761.0            35761.0
# Zimbabwe      ZWE  2021-03-10             35901.0            35901.0
# Zimbabwe      ZWE  2021-03-11             36019.0            36019.0
#
#           people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# country
# ...

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv', header=None)
i
# Out:
#             0         1           2                   3                  4   \
# 0      country  iso_code        date  total_vaccinations  people_vaccinated
# 1      Albania       ALB  2021-01-10                 0.0                0.0
# 2      Albania       ALB  2021-01-11                 NaN                NaN
# 3      Albania       ALB  2021-01-12               128.0              128.0
# 4      Albania       ALB  2021-01-13               188.0              188.0
# ...        ...       ...         ...                 ...                ...
# 5968  Zimbabwe       ZWE  2021-03-07             32240.0            32240.0
# 5969  Zimbabwe       ZWE  2021-03-08             35518.0            35518.0
# 5970  Zimbabwe       ZWE  2021-03-09             35761.0            35761.0
# 5971  Zimbabwe       ZWE  2021-03-10             35901.0            35901.0
# 5972  Zimbabwe       ZWE  2021-03-11             36019.0            36019.0
#
# ...

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv', names=[11,22,33,44,55,66,77])
i
# Out:
#                                                                                                                                                                  11  \
# country  iso_code date       total_vaccinations people_vaccinated people_fully_vaccinated daily_vaccinations_raw daily_vaccinations  total_vaccinations_per_hundred
# Albania  ALB      2021-01-10 0.0                0.0               NaN                     NaN                    NaN                                            0.0
#                   2021-01-11 NaN                NaN               NaN                     NaN                    64.0                                           NaN
#                   2021-01-12 128.0              128.0             NaN                     NaN                    64.0                                           0.0
#                   2021-01-13 188.0              188.0             NaN                     60.0                   63.0                                          0.01
# ...

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv')
i.shape
# Out:
# (5972, 15)

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv')
i.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
import pandas as pd

i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv')
newDataset = i.drop(columns ='source_website')
newDataset
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-10                 0.0                0.0
# 1      Albania      ALB  2021-01-11                 NaN                NaN
# 2      Albania      ALB  2021-01-12               128.0              128.0
# 3      Albania      ALB  2021-01-13               188.0              188.0
# 4      Albania      ALB  2021-01-14               266.0              266.0
# ...        ...      ...         ...                 ...                ...
# 5967  Zimbabwe      ZWE  2021-03-07             32240.0            32240.0
# 5968  Zimbabwe      ZWE  2021-03-08             35518.0            35518.0
# 5969  Zimbabwe      ZWE  2021-03-09             35761.0            35761.0
# 5970  Zimbabwe      ZWE  2021-03-10             35901.0            35901.0
# 5971  Zimbabwe      ZWE  2021-03-11             36019.0            36019.0
#
# ...

# %%
i = pd.read_csv('E:\Monali\Class\Class Material\DataSets\country_vaccinations.csv\country_vaccinations.csv')
newDataset = i.drop(columns ='source_website')
newDataset.select_dtypes(include=["int64","float64"]).columns
# Out:
# Index(['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred',
#        'daily_vaccinations_per_million'],
#       dtype='object')

# %%
newDataset.isnull()
# Out:
#       country  iso_code   date  total_vaccinations  people_vaccinated  \
# 0       False     False  False               False              False
# 1       False     False  False                True               True
# 2       False     False  False               False              False
# 3       False     False  False               False              False
# 4       False     False  False               False              False
# ...       ...       ...    ...                 ...                ...
# 5967    False     False  False               False              False
# 5968    False     False  False               False              False
# 5969    False     False  False               False              False
# 5970    False     False  False               False              False
# 5971    False     False  False               False              False
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
newDataset.isnull().sum()
# Out:
# country                                   0
# iso_code                                352
# date                                      0
# total_vaccinations                     2170
# people_vaccinated                      2590
# people_fully_vaccinated                3663
# daily_vaccinations_raw                 2774
# daily_vaccinations                      190
# total_vaccinations_per_hundred         2170
# people_vaccinated_per_hundred          2590
# people_fully_vaccinated_per_hundred    3663
# daily_vaccinations_per_million          190
# vaccines                                  0
# source_name                               0
# dtype: int64

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

newDataset.isnull().sum()
# Out:
# country                                   0
# iso_code                                352
# date                                      0
# total_vaccinations                     2170
# people_vaccinated                      2590
# people_fully_vaccinated                3663
# daily_vaccinations_raw                 2774
# daily_vaccinations                      190
# total_vaccinations_per_hundred         2170
# people_vaccinated_per_hundred          2590
# people_fully_vaccinated_per_hundred    3663
# daily_vaccinations_per_million          190
# vaccines                                  0
# source_name                               0
# dtype: int64

# %%
newDataset.isnull().sum().sum()
# Out:
# 20352

# %%
newSetDataSet1 = newDataset.select_dtypes(include=["int64","float64"]).columns
newSetDataSet1
# Out:
# Index(['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred',
#        'daily_vaccinations_per_million'],
#       dtype='object')

# %%
newSetDataSet1.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False])

# %%
newSetDataSet1.isnull().sum()
# Out:
# 0

# %%
pd.set_option('display.max_columns',None)

pd.set_option('display.max_rows',None)
newSetDataSet1.isnull().sum()
# Out:
# 0
